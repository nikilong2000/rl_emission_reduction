# %%
import pandas as pd

df = pd.read_csv(r'/Users/niklaslongschiefelbein/local_documents/THESIS/code/rl_emission_reduction/internal_lstm_models/NN_Application/Output/20260202_144315_results_WLTC/data_with_predictions.csv', sep=";")

# %%
print(df['Car_Speed_kmph_pred'].iloc[-40:])
# Out:
# 3561    43.741924
# 3562    41.959110
# 3563    40.203796
# 3564    38.511086
# 3565    36.904564
# 3566    35.406360
# 3567    34.020880
# 3568    32.758610
# 3569    31.601131
# 3570    30.512981
# 3571    29.458492
# 3572    28.409150
# 3573    27.351545
# 3574    26.279099
# 3575    25.188742
# 3576    24.073952
# 3577    22.927273
# 3578    21.715862
# 3579    20.436079
# 3580    19.038250
# 3581    17.524338
# 3582    15.882120
# 3583    14.131521
# 3584    12.307846
# 3585    10.474634
# 3586     8.709307
# 3587     6.997197
# 3588     5.110753
# 3589     3.028402
# 3590     1.544901
# 3591     1.390390
# 3592     3.619810
# 3593     1.669763
# 3594     0.532005
# 3595     0.092371
# 3596    -0.053821
# 3597    -0.071982
# 3598    -0.040189
# 3599     0.002937
# 3600     0.038503
# Name: Car_Speed_kmph_pred, dtype: float64
