# %% [markdown]
# ## LIBRARIES

# %%
import tensorflow as tf
from joblib import load

# Imports controller model from models.py
from models import ScaledController

# Imports main training function from trainer.py
from trainer_EVALUATION import train_and_save_controller
# Out:
# 2025-10-14 10:34:13.437267: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-14 10:34:13.456032: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-14 10:34:13.456048: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-14 10:34:13.456745: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-14 10:34:13.460632: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-14 10:34:13.865980: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/usuaris.new/artur.aubach/Antic_RL_Cotxe/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/usuaris.new/artur.aubach/Antic_RL_Cotxe/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ## MODELS

# %%
scaler = load("../src/escalados/gbm_v1.lib")
scaler_params = {
    "data_min": scaler.data_min_,   # 6 values
    "data_max": scaler.data_max_,   # 6 values
    "scale":    scaler.scale_,      # 6 values  (1/(max-min) or 2/(max-min))
    "min":      scaler.min_,        # 6 values  (offset)
}

controller = ScaledController(scaler_params, units=128, alpha=1000)

# %%
# Example parameters
epochs     = 10000
alpha, beta, gamma = 1.0, 0, 0

NOx_mean = tf.constant(0.0001663531, dtype=tf.float32)
CO_mean  = tf.constant(0.0013611736, dtype=tf.float32)
# For velocity term, divide by 1.0 (or change to something more realistic if you have standard deviation)
vel_norm = tf.constant(1.0, dtype=tf.float32)

alpha = alpha/vel_norm
beta = beta/NOx_mean
gamma = gamma/CO_mean



name       = "V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best"


# Execute training and saving
out_dir, losses = train_and_save_controller(
    epochs,
    alpha, beta, gamma,
    name,
    ruta_ICE="../src/models_markus/ICE_Model_Update_01",
    ruta_PG="../src/models_markus/PG_Model_M1.1_without_EM1_Torque",
    controller=controller,
    learning_rate=1e-4,
    output_root="models",
    clipping= True,
    evalue= True,
    vel_target = 75.,
    plateau_patience = 10,
    early_stop_patience = 24,
    warmup_steps = 600,
    good_loss =0.05,
)


print("All done in:", out_dir)

# %%
scaler = load("../src/escalados/gbm_v2.lib")
scaler_params = {
    "data_min": scaler.data_min_,   # 6 values
    "data_max": scaler.data_max_,   # 6 values
    "scale":    scaler.scale_,      # 6 values  (1/(max-min) or 2/(max-min))
    "min":      scaler.min_,        # 6 values  (offset)
}

controller = ScaledController(scaler_params, units=128, alpha=1000)

# %%
# Example parameters
epochs     = 10000
alpha, beta, gamma = 1.0, 0, 0

NOx_mean = tf.constant(0.0001663531, dtype=tf.float32)
CO_mean  = tf.constant(0.0013611736, dtype=tf.float32)
# For velocity term, divide by 1.0 (or change to something more realistic if you have standard deviation)
vel_norm = tf.constant(1.0, dtype=tf.float32)

alpha = alpha/vel_norm
beta = beta/NOx_mean
gamma = gamma/CO_mean



name       = "111V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best"


# Execute training and saving
# Execute training and saving
out_dir, losses = train_and_save_controller(
    epochs,
    alpha, beta, gamma,
    name,
    ruta_ICE="../src/models_markus/ICE_Model_Update_01",
    ruta_PG="../src/models_markus/PG_Model_M1.1_without_EM1_Torque",
    controller=controller,
    learning_rate=1e-4,
    output_root="models",
    clipping= True,
    evalue= True,
    vel_target = 75.,
    plateau_patience = 10,
    early_stop_patience = 24,
    warmup_steps = 300,
    good_loss =0.05,

)


print("All done in:", out_dir)

# %% [markdown]
# ## EVALUATION

# %%
scaler = load("../src/escalados/gbm_v1.lib")
scaler_params = {
    "data_min": scaler.data_min_,   # 6 values
    "data_max": scaler.data_max_,   # 6 values
    "scale":    scaler.scale_,      # 6 values  (1/(max-min) or 2/(max-min))
    "min":      scaler.min_,        # 6 values  (offset)
}

controller = ScaledController(scaler_params, units=128, alpha=1000)

# Example parameters
epochs     = 10000
alpha, beta, gamma = 1.0, 0, 0

NOx_mean = tf.constant(0.0001663531, dtype=tf.float32)
CO_mean  = tf.constant(0.0013611736, dtype=tf.float32)
# For velocity term, divide by 1.0 (or change to something more realistic if you have standard deviation)
vel_norm = tf.constant(1.0, dtype=tf.float32)

alpha = alpha/vel_norm
beta = beta/NOx_mean
gamma = gamma/CO_mean



name       = "V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best"


# Execute training and saving
out_dir, losses = train_and_save_controller(
    epochs,
    alpha, beta, gamma,
    name,
    ruta_ICE="../src/models_markus/ICE_Model_Update_01",
    ruta_PG="../src/models_markus/PG_Model_M1.1_without_EM1_Torque",
    controller=controller,
    learning_rate=1e-4,
    output_root="models",
    clipping= True,
    evalue= True,
    vel_target = 75.,
    plateau_patience = 10,
    early_stop_patience = 24,
    warmup_steps = 75,
    good_loss =0.5,
    profile_training=True
    )


print("All done in:", out_dir)
# Out:
# 2025-10-14 10:34:15.000231: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-14 10:34:15.028332: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 🔍 Intentando cargar modelo desde: ../src/models_markus/ICE_Model_Update_01/model.h5
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 🔍 Intentando cargar modelo desde: ../src/models_markus/PG_Model_M1.1_without_EM1_Torque/model.h5
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /home/usuaris.new/artur.aubach/Antic_RL_Cotxe/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.3.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/usuaris.new/artur.aubach/Antic_RL_Cotxe/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /home/usuaris.new/artur.aubach/Antic_RL_Cotxe/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [Seed 0] loss corto: 156.1354
# [Seed 1] loss corto: 153.5182
# [Seed 2] loss corto: 29.2540
# ⚡ Usando semilla con loss corto mejor: 29.2540
#
# --- Iniciant bucle principal d'entrenament de 10000 èpoques ---
# Epoch 1/10000 — Loss mitjana: 10.0251
# Epoch 2/10000 — Loss mitjana: 5.3954
# Epoch 3/10000 — Loss mitjana: 5.1704
# Epoch 4/10000 — Loss mitjana: 186.0758
# Epoch 5/10000 — Loss mitjana: 70.1979
# Epoch 6/10000 — Loss mitjana: 4.6284
# Epoch 7/10000 — Loss mitjana: 11.9417
# Epoch 8/10000 — Loss mitjana: 15.0132
# Epoch 9/10000 — Loss mitjana: 0.2411
# 🔄 warmup_steps 100 → 75 (reset LR)
# Epoch 10/10000 — Loss mitjana: 46.7800
# Epoch 11/10000 — Loss mitjana: 4.5794
# Epoch 12/10000 — Loss mitjana: 3.6146
# Epoch 13/10000 — Loss mitjana: 3.3743
# Epoch 14/10000 — Loss mitjana: 1.2792
# Epoch 15/10000 — Loss mitjana: 10.0940
# Epoch 16/10000 — Loss mitjana: 29.6965
# Epoch 17/10000 — Loss mitjana: 2.8705
# Epoch 18/10000 — Loss mitjana: 14.0438
# Epoch 19/10000 — Loss mitjana: 10.9391
# Epoch 20/10000 — Loss mitjana: 13.3266
# Epoch 21/10000 — Loss mitjana: 10.0341
# Epoch 22/10000 — Loss mitjana: 3.0446
# Epoch 23/10000 — Loss mitjana: 17.0651
# Epoch 24/10000 — Loss mitjana: 1.4549
#   ↳ Restaurats els millors pesos abans de reduir el LR.
#   ↳ No millorat en 10 èpoques — LR 1.00e-04 → 5.00e-05
# Epoch 25/10000 — Loss mitjana: 7.8625
# Epoch 26/10000 — Loss mitjana: 1.1142
# Epoch 27/10000 — Loss mitjana: 26.3486
# Epoch 28/10000 — Loss mitjana: 11.8448
# Epoch 29/10000 — Loss mitjana: 14.5983
# Epoch 30/10000 — Loss mitjana: 8.0759
# Epoch 31/10000 — Loss mitjana: 0.8317
# Epoch 32/10000 — Loss mitjana: 5.8526
# Epoch 33/10000 — Loss mitjana: 18.4624
# Epoch 34/10000 — Loss mitjana: 6.2548
# Epoch 35/10000 — Loss mitjana: 15.4080
# Epoch 36/10000 — Loss mitjana: 18.2971
# Epoch 37/10000 — Loss mitjana: 37.2186
# Epoch 38/10000 — Loss mitjana: 15.0001
# Epoch 39/10000 — Loss mitjana: 12.4479
# Epoch 40/10000 — Loss mitjana: 0.3144
# 🔄 warmup_steps 75 → 50 (reset LR)
# Epoch 41/10000 — Loss mitjana: 32.2008
# Epoch 42/10000 — Loss mitjana: 3.0948
# Epoch 43/10000 — Loss mitjana: 52.5803
# Epoch 44/10000 — Loss mitjana: 0.8642
# Epoch 45/10000 — Loss mitjana: 4.4957
# Epoch 46/10000 — Loss mitjana: 1.5310
# Epoch 47/10000 — Loss mitjana: 53.9804
# Epoch 48/10000 — Loss mitjana: 2.1586
# Epoch 49/10000 — Loss mitjana: 2.4412
# Epoch 50/10000 — Loss mitjana: 2.2539
# Epoch 51/10000 — Loss mitjana: 13.7438
# Epoch 52/10000 — Loss mitjana: 25.5427
# Epoch 53/10000 — Loss mitjana: 3.6463
# Epoch 54/10000 — Loss mitjana: 13.0295
#   ↳ Restaurats els millors pesos abans de reduir el LR.
#   ↳ No millorat en 10 èpoques — LR 1.00e-04 → 5.00e-05
# Epoch 55/10000 — Loss mitjana: 8.1795
# Epoch 56/10000 — Loss mitjana: 3.0075
# Epoch 57/10000 — Loss mitjana: 1.5410
# Epoch 58/10000 — Loss mitjana: 44.1272
# Epoch 59/10000 — Loss mitjana: 2.0599
# Epoch 60/10000 — Loss mitjana: 2.0550
# Epoch 61/10000 — Loss mitjana: 4.4218
# Epoch 62/10000 — Loss mitjana: 13.5583
# Epoch 63/10000 — Loss mitjana: 0.8003
# Epoch 64/10000 — Loss mitjana: 0.7392
# Epoch 65/10000 — Loss mitjana: 0.4021
# 🔄 warmup_steps 50 → 25 (reset LR)
# Epoch 66/10000 — Loss mitjana: 76.9271
# Epoch 67/10000 — Loss mitjana: 1.1292
# Epoch 68/10000 — Loss mitjana: 8.2113
# Epoch 69/10000 — Loss mitjana: 1.0960
# Epoch 70/10000 — Loss mitjana: 0.6513
# Epoch 71/10000 — Loss mitjana: 2.2355
# Epoch 72/10000 — Loss mitjana: 28.2802
# Epoch 73/10000 — Loss mitjana: 3.0593
# Epoch 74/10000 — Loss mitjana: 19.4514
# Epoch 75/10000 — Loss mitjana: 1329.3361
# Epoch 76/10000 — Loss mitjana: 195.6740
# Epoch 77/10000 — Loss mitjana: 103.6162
# Epoch 78/10000 — Loss mitjana: 203.9904
# Epoch 79/10000 — Loss mitjana: 319.7800
# Epoch 80/10000 — Loss mitjana: 395.4483
#   ↳ Restaurats els millors pesos abans de reduir el LR.
#   ↳ No millorat en 10 èpoques — LR 1.00e-04 → 5.00e-05
# Epoch 81/10000 — Loss mitjana: 12.0389
# Epoch 82/10000 — Loss mitjana: 0.2944
# Epoch 83/10000 — Loss mitjana: 18.6138
# Epoch 84/10000 — Loss mitjana: 0.4328
# Epoch 85/10000 — Loss mitjana: 16.7699
# Epoch 86/10000 — Loss mitjana: 34.7340
# Epoch 87/10000 — Loss mitjana: 0.1083
# Epoch 88/10000 — Loss mitjana: 4.2649
# Epoch 89/10000 — Loss mitjana: 8.8988
# Epoch 90/10000 — Loss mitjana: 52.6430
# Epoch 91/10000 — Loss mitjana: 1.2997
# Epoch 92/10000 — Loss mitjana: 2.4682
# Epoch 93/10000 — Loss mitjana: 1.0485
# Epoch 94/10000 — Loss mitjana: 1.4803
# Epoch 95/10000 — Loss mitjana: 1.0481
# Epoch 96/10000 — Loss mitjana: 71.3966
# Epoch 97/10000 — Loss mitjana: 68.1567
#   ↳ Restaurats els millors pesos abans de reduir el LR.
#   ↳ No millorat en 10 èpoques — LR 5.00e-05 → 2.50e-05
# Epoch 98/10000 — Loss mitjana: 2.9000
# Epoch 99/10000 — Loss mitjana: 37.8456
# Epoch 100/10000 — Loss mitjana: 37.8202
# Epoch 101/10000 — Loss mitjana: 3.2561
# Epoch 102/10000 — Loss mitjana: 1.6923
# Epoch 103/10000 — Loss mitjana: 75.3976
# Epoch 104/10000 — Loss mitjana: 1.1343
# Epoch 105/10000 — Loss mitjana: 1.5694
# Epoch 106/10000 — Loss mitjana: 3.7786
# Epoch 107/10000 — Loss mitjana: 21.2817
#   ↳ Restaurats els millors pesos abans de reduir el LR.
#   ↳ No millorat en 10 èpoques — LR 2.50e-05 → 1.25e-05
# Epoch 108/10000 — Loss mitjana: 5.6859
# Epoch 109/10000 — Loss mitjana: 5.6251
# Epoch 110/10000 — Loss mitjana: 0.0682
# Epoch 111/10000 — Loss mitjana: 8.7596
# Epoch 112/10000 — Loss mitjana: 12.2260
# Epoch 113/10000 — Loss mitjana: 0.0869
# Epoch 114/10000 — Loss mitjana: 79.4442
# Epoch 115/10000 — Loss mitjana: 4.4273
# Epoch 116/10000 — Loss mitjana: 19.7982
# Epoch 117/10000 — Loss mitjana: 32.0121
# Epoch 118/10000 — Loss mitjana: 13.8191
# Epoch 119/10000 — Loss mitjana: 2.9061
# Epoch 120/10000 — Loss mitjana: 8.7068
#   ↳ Restaurats els millors pesos abans de reduir el LR.
#   ↳ No millorat en 10 èpoques — LR 1.25e-05 → 6.25e-06
# Epoch 121/10000 — Loss mitjana: 42.7366
# Epoch 122/10000 — Loss mitjana: 36.8668
# Epoch 123/10000 — Loss mitjana: 31.5200
# Epoch 124/10000 — Loss mitjana: 4.3624
# Epoch 125/10000 — Loss mitjana: 28.8161
# Epoch 126/10000 — Loss mitjana: 89.2350
# Epoch 127/10000 — Loss mitjana: 0.0369
# Epoch 128/10000 — Loss mitjana: 26.4233
# Epoch 129/10000 — Loss mitjana: 10.4813
# Epoch 130/10000 — Loss mitjana: 34.6575
# Epoch 131/10000 — Loss mitjana: 14.6686
# Epoch 132/10000 — Loss mitjana: 0.1377
# Epoch 133/10000 — Loss mitjana: 0.2530
# Epoch 134/10000 — Loss mitjana: 74.0332
# Epoch 135/10000 — Loss mitjana: 1.7856
# Epoch 136/10000 — Loss mitjana: 7.2378
# Epoch 137/10000 — Loss mitjana: 72.3603
#   ↳ Restaurats els millors pesos abans de reduir el LR.
#   ↳ No millorat en 10 èpoques — LR 6.25e-06 → 3.12e-06
# Epoch 138/10000 — Loss mitjana: 5.9667
# Epoch 139/10000 — Loss mitjana: 24.1634
# Epoch 140/10000 — Loss mitjana: 87.7897
# Epoch 141/10000 — Loss mitjana: 4.1366
# Epoch 142/10000 — Loss mitjana: 9.7888
# Epoch 143/10000 — Loss mitjana: 0.7113
# Epoch 144/10000 — Loss mitjana: 11.6217
# Epoch 145/10000 — Loss mitjana: 14.6957
# Epoch 146/10000 — Loss mitjana: 72.7114
# Epoch 147/10000 — Loss mitjana: 0.1564
#   ↳ Restaurats els millors pesos abans de reduir el LR.
#   ↳ No millorat en 10 èpoques — LR 3.12e-06 → 1.56e-06
# Epoch 148/10000 — Loss mitjana: 19.0018
# Epoch 149/10000 — Loss mitjana: 3.9422
# Epoch 150/10000 — Loss mitjana: 15.3228
# Epoch 151/10000 — Loss mitjana: 0.1704
# ⚠️ Early stopping: no millora en 24 èpoques.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best/assets
# INFO:tensorflow:Assets written to: models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# ✔ Model guardat en models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best
# ✔ Gràfic de pèrdua guardat en models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g/loss.png
# ─── Pérdida media últimas 200 iteraciones ───
# |75.0-vel|: 1.6021
# NOx    : 0.0349
# CO     : 0.0006
#
# --- Generant anàlisi de rendiment ---
#
# --- ANÀLISI DE RENDIMENT DEL ROLLOUT ---
# [PROFILING] Dades de temps guardades a: models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g/profiling_rollout_data.csv
#
# [PROFILING] Resum del temps per 'rollout_and_loss' (en segons):
# count    151.000000
# mean       1.466196
# std        0.872540
# min        1.338549
# 25%        1.340654
# 50%        1.341789
# 75%        1.343265
# max        7.629511
# Name: duration, dtype: float64
# [PROFILING] Gràfic Boxplot guardat a: models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g/profiling_rollout_boxplot.html
# [PROFILING] Gràfic d'evolució guardat a: models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g/profiling_rollout_evolution.html
# ✔ Gràfic interactiu guardat en models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g/traj_final.html
# Todo listo en: models/V2.3_perf_control_5_values_clipping_mse_complexlr3_warm_reductlr_best_75.0velTarget_100warmup_0.5good_loss_10000ep_1.00a_0.00b_0.00g

# %% [markdown]
# ## PLOTS FOR THRESHOLDS

# %%
import numpy as np
import matplotlib.pyplot as plt

# Valores de alpha solicitados
alphas = [0.75, 0.5, 0.25, 0.2, 0.01, 0.005, 0.001]
threshold = 900.0

# Dominio alrededor del umbral
x = np.linspace(700, 1100, 400)

plt.figure(figsize=(8, 5))
for alpha in alphas:
    y = 1 / (1 + np.exp(-alpha * (x - threshold)))
    plt.plot(x, y, label=f"alpha = {alpha}")

plt.xlabel('Valor de y₀')
plt.ylabel('g = sigmoid(alpha*(y₀ - threshold))')
plt.title('Sigmoide con varios valores de alpha y threshold = 900')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Valores de alpha solicitados
alphas = [0.75, 0.5, 0.25, 0.2, 0.01, 0.005, 0.001, 100, 250]
threshold = -0.6

# Dominio -1 a 1 con buena resolución
x = np.linspace(-1, 1, 400)

plt.figure(figsize=(8, 5))
for alpha in alphas:
    y = 1 / (1 + np.exp(-alpha * (x - threshold)))
    plt.plot(x, y, label=f"alpha = {alpha}")

# Línea vertical en el umbral
plt.axvline(threshold, linestyle="--", alpha=0.7)

plt.xlabel('Valor de y₀')
plt.ylabel('g = sigmoid(alpha*(y₀ - threshold))')
plt.title('Sigmoide con varios valores de alpha y threshold = -0.6 (dominio -1 a 1)')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters from your model
alpha = 1000
tau_norm = -0.9375

# Generate a range of ice_norm values around the threshold
x = np.linspace(tau_norm - 0.5, tau_norm + 0.5, 400)

# Gate function
gate = 1 / (1 + np.exp(-(x - tau_norm) * alpha))

# Plot
plt.figure()
plt.plot(x, gate, label="gate = σ((ice_norm - τ_norm)·α)")
plt.axvline(tau_norm, linestyle='--', label="τ_norm")
plt.xlabel("ice_norm")
plt.ylabel("gate value")
plt.title("Effect of α=0.01 on the gating sigmoid")
plt.legend()
plt.grid(True)

plt.show()

# %%
def rescale(x, old_min, old_max, new_min, new_max):
    return (x - old_min) / (old_max - old_min) * (new_max - new_min) + new_min

old_min, old_max = 0, 4500
new_min, new_max = -1, 1
threshold = 900.0

rescaled_threshold = rescale(threshold, old_min, old_max, new_min, new_max)
print(rescaled_threshold)  # Salida: -0.6
